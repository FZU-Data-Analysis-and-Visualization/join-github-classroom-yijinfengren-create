# %% [markdown]
# # 数据分析可视化报告

# %%
print("hello world!")
# Out:
# hello world!

# %%
pip install numpy
# Out:
# ...
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/15.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.9 MB 985.5 kB/s eta 0:00:16
#    - -------------------------------------- 0.5/15.9 MB 985.5 kB/s eta 0:00:16
#    - -------------------------------------- 0.8/15.9 MB 1.0 MB/s eta 0:00:15
#    -- ------------------------------------- 1.0/15.9 MB 986.7 kB/s eta 0:00:16
#    --- ------------------------------------ 1.6/15.9 MB 1.3 MB/s eta 0:00:11
#    ----- ---------------------------------- 2.1/15.9 MB 1.4 MB/s eta 0:00:10
#    ----- ---------------------------------- 2.4/15.9 MB 1.4 MB/s eta 0:00:10
#    ------ --------------------------------- 2.6/15.9 MB 1.5 MB/s eta 0:00:09
# ...

# %%
import numpy as np
print(numpy)
# Out:
# <module 'numpy' from 'd:\\minianaconda\\envs\\shujufenxikeshihua\\lib\\site-packages\\numpy\\__init__.py'>

# %%
np.zeros((3, 3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.ones((3, 3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.],
#        [1., 1., 1.]])
